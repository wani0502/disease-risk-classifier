# %%
import sys
sys.path.append("..")
from src.preprocessing import prepare_data

# Clean version (for class_weight)
X_train, X_test, y_train, y_test, scaler = prepare_data(
    use_binary_target=True,
    apply_smote=False,
    save_dir="../data/processed"
)

print("\n" + "="*60)

# SMOTENC version
X_train_smote, X_test_smote, y_train_smote, y_test_smote, _ = prepare_data(
    use_binary_target=True,
    apply_smote=True,
    save_dir="../data/processed"
)
# Out:
# Saved processed data to ..\data\processed
#
# Train shape: (202944, 21) | Test shape: (50736, 21)
# Target distribution (train):
# target
# 0    0.8424
# 1    0.1576
# Name: proportion, dtype: float64
#
# ...
# Saved processed data to ..\data\processed
#
# Train shape: (341924, 21) | Test shape: (50736, 21)
# Target distribution (train):
# target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
# (SMOTENC applied – train set is now balanced)

# %%
print("Features used:", list(X_train.columns))
print("\nContinuous features are scaled (should have mean ≈ 0, std ≈ 1):")
print(X_train[["BMI", "MentHlth", "PhysHlth", "Age"]].describe().round(3))

print("\nBinary / ordinal left as-is (example):")
print(X_train[["HighBP", "GenHlth", "Income"]].head())
# Out:
# Features used: ['BMI', 'MentHlth', 'PhysHlth', 'Age', 'HighBP', 'HighChol', 'CholCheck', 'Smoker', 'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'DiffWalk', 'Sex', 'GenHlth', 'Education', 'Income']
#
# Continuous features are scaled (should have mean ≈ 0, std ≈ 1):
#               BMI    MentHlth    PhysHlth         Age
# count  202944.000  202944.000  202944.000  202944.000
# mean       -0.000       0.000      -0.000       0.000
# std         1.000       1.000       1.000       1.000
# min        -2.480      -0.429      -0.486      -2.302
# 25%        -0.664      -0.429      -0.486      -0.666
# 50%        -0.210      -0.429      -0.486      -0.012
# 75%         0.395      -0.159      -0.142       0.642
# max        10.532       3.622       2.956       1.624
#
# Binary / ordinal left as-is (example):
#         HighBP  GenHlth  Income
# 124535     1.0      4.0     6.0
# 14723      0.0      3.0     8.0
# ...
